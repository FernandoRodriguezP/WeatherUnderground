# %% [markdown]
# # Weather Underground Web API

# %% [markdown]
# El siguiente Python Notebook muestra cómo obtener datos meteorológicos de cualquier aeropuerto del mundo, en formato horario.<br>
# Estos datos históricos proceden de <b>Weather Underground</b> (https://www.wunderground.com/).<br><br>
# Para configurar la búsqueda, es necesario especificar tres campos:<br>
# <li>api-key: Se puede obtener en el siguiente [enlace](https://espanol.wunderground.com/weather/api).</li>
# <li>query-date: Fecha de extracción deseada en formato *'YYYYMMDD'*.</li>
# <li>IATA_code: Código del aeropuerto, disponible [aquí](https://www.world-airport-codes.com/).</li>

# %%
import pandas as pd
import requests
import json
from datetime import datetime as dt

# %%
#Wunderground API Key
api_key = '****************'

# %%
#Format YYYYMMDD
query_date = '20180203'

# %%
#Airport Code
IATA_code = 'LEBL'

# %%
#url para extraer datos históricos horarios en función de la fecha y del aeropuerto
url = 'http://api.wunderground.com/api/' + api_key + '/history_' + query_date + '/q/' + IATA_code + '.json'

# %%
data = requests.get(url)

# %%
data.content
# Out:
# b'\n{\n  "response": {\n  "version":"0.1",\n  "termsofService":"http://www.wunderground.com/weather/api/d/terms.html",\n  "features": {\n  "history": 1\n  }\n\t}\n\t\t,\n\t"history": {\n\t\t"date": {\n\t\t"pretty": "February 3, 2018",\n\t\t"year": "2018",\n\t\t"mon": "02",\n\t\t"mday": "03",\n\t\t"hour": "00",\n\t\t"min": "00",\n\t\t"tzname": "Europe/Madrid"\n\t\t},\n\t\t"utcdate": {\n\t\t"pretty": "February 2, 2018",\n\t\t"year": "2018",\n\t\t"mon": "02",\n\t\t"mday": "02",\n\t\t"hour": "23",\n\t\t"min": "00",\n\t\t"tzname": "UTC"\n\t\t},\n\t\t"observations": [\n\t\t{\n\t\t"date": {\n\t\t"pretty": "12:00 AM CET on February 03, 2018",\n\t\t"year": "2018",\n\t\t"mon": "02",\n\t\t"mday": "03",\n\t\t"hour": "00",\n\t\t"min": "00",\n\t\t"tzname": "Europe/Madrid"\n\t\t},\n\t\t"utcdate": {\n\t\t"pretty": "11:00 PM GMT on February 02, 2018",\n\t\t"year": "2018",\n\t\t"mon": "02",\n\t\t"mday": "02",\n\t\t"hour": "23",\n\t\t"min": "00",\n\t\t"tzname": "UTC"\n\t\t},\n\t\t"tempm":"5", "tempi":"41","dewptm":"-6", "dewpti":"21","hum":"32","wspdm":"13.0", "wspdi":"8.1","wgustm":"", "wgusti":"","wdird":"0","wdire":"North","vism":"30", "visi":"19","pressurem":"1009", "pressurei":"29.81","windchillm":"-999", "windchilli":"-999","heatindexm":"-9999", "heatindexi":"-9999","precipm":"", "precipi":"","conds":"","icon":"","fog":"0","rain":"0","snow":"0","hail":"0","thunder":"0","tornado":"0","metar":"AAXX 02234 08181 45/80 /3607 10051 21059 30088 40094 51010" },\n\t\t{\n\t\t"date": {\n\t\t"pretty": "12:00 AM CET on February 03, 2018",\n\t\t"year": "2018",\n\t\t"mon": "02",\n\t\t"mday": "03",\n\t\t"hour": "00",\n\t\t"min": "00",\n\t\t"tzname": "Europe/Madrid"\n\t\t},\n\t\t"utcdate": {\n\t\t"pretty": "11:00 PM GMT on February 02, 2018",\n\t\t"year": "2018",\n\t\t"mon": "02",\n\t\t"mday": "02",\n\t\t"hour": "23",\n\t\t"min": "00",\n\t\t"tzname": "UTC"\n\t\t},\n\t\t"tempm":"5.0", "tempi":"41.0","dewptm":"-6.0", "dewpti":"21.2","hum":"45","wspdm":"18.5", "wspdi":"11.5","wgustm":"-9999.0", "wgusti":"-9999.0","wdird":"320","wdire":"NW","vism":"-9999.0", "visi":"-9999.0","pressurem":"1009", "pressurei":"29.80","windchillm":"1.3", "windchilli":"34.3","heatindexm":"-9999", "heatindexi":"-9999","precipm":"-9999.00", "precipi":"-9999.00","conds":"Clear","icon":"clear","fog":"0","rain":"0","snow":"0","hail":"0","thunder":"0","tornado":"0","metar":"METAR LEBL 022300Z 32010KT CAVOK 05/M06 Q1009 NOSIG" },\n\t\t{\n\t\t"date": {\n\t\t"pretty": "12:30 AM CET on February 03, 2018",\n\t\t"year": "2018",\n\t\t"mon": "02",\n\t\t"mday": "03",\n\t\t"hour": "00",\n\t\t"min": "30",\n\t\t"tzname": "Europe/Madrid"\n\t\t},\n\t\t"utcdate": {\n\t\t"pretty": "11:30 PM GMT on February 02, 2018",\n\t\t"year": "2018",\n\t\t"mon": "02",\n\t\t"mday": "02",\n\t\t"hour": "23",\n\t\t"min": "30",\n\t\t"tzname": "UTC"\n\t\t},\n\t\t"tempm":"4.0", "tempi":"39.2","dewptm":"-6.0", "dewpti":"21.2","hum":"49","wspdm":"18.5", "wspdi":"11.5","wgustm":"-9999.0", "wgusti":"-9999.0","wdird":"320","wdire":"NW","vism":"-9999.0", "visi":"-9999.0","pressurem":"1009", "pressurei":"29.80","windchillm":"0.0", "windchilli":"32.0","heatindexm":"-9999", "heatindexi":"-9999","precipm":"-9999.00", "precipi":"-9999.00","conds":"Clear","icon":"clear","fog":"0","rain":"0","snow":"0","hail":"0","thunder":"0","tornado":"0","metar":"METAR LEBL 022330Z 32010KT CAVOK 04/M06 Q1009 NOSIG" },\n\t\t{\n\t\t"date": {\n\t\t"pretty": "1:00 AM CET on February 03, 2018",\n\t\t"year": "2018",\n\t\t"mon": "02",\n\t\t"mday": "03",\n\t\t"hour": "01",\n\t\t"min": "00",\n\t\t"tzname": "Europe/Madrid"\n\t\t},\n\t\t"utcdate": {\n\t\t"pretty": "12:00 AM GMT on February 03, 2018",\n\t\t"year": "2018",\n\t\t"mon": "02",\n\t\t"mday": "03",\n\t\t"hour": "00",\n\t\t"min": "00",\n\t\t"tzname": "UTC"\n\t\t},\n\t\t"tempm":"4.0", "tempi":"39.2","dewptm":"-6.0", "dewpti":"21.2","hum":"49","wspdm":"20.4", "wspdi":"12.7","wgustm":"-9999.0", "wgusti":"-9999.0","wdird":"320","wdire":"NW","vism":"-9999.0", "visi":"-9999.0","pressurem":"1009", "pressurei" ...

# %%
contenido = json.loads(data.content)
print(contenido)
# Out:
# {'response': {'version': '0.1', 'termsofService': 'http://www.wunderground.com/weather/api/d/terms.html', 'features': {'history': 1}}, 'history': {'date': {'pretty': 'February 3, 2018', 'year': '2018', 'mon': '02', 'mday': '03', 'hour': '00', 'min': '00', 'tzname': 'Europe/Madrid'}, 'utcdate': {'pretty': 'February 2, 2018', 'year': '2018', 'mon': '02', 'mday': '02', 'hour': '23', 'min': '00', 'tzname': 'UTC'}, 'observations': [{'date': {'pretty': '12:00 AM CET on February 03, 2018', 'year': '2018', 'mon': '02', 'mday': '03', 'hour': '00', 'min': '00', 'tzname': 'Europe/Madrid'}, 'utcdate': {'pretty': '11:00 PM GMT on February 02, 2018', 'year': '2018', 'mon': '02', 'mday': '02', 'hour': '23', 'min': '00', 'tzname': 'UTC'}, 'tempm': '5', 'tempi': '41', 'dewptm': '-6', 'dewpti': '21', 'hum': '32', 'wspdm': '13.0', 'wspdi': '8.1', 'wgustm': '', 'wgusti': '', 'wdird': '0', 'wdire': 'North', 'vism': '30', 'visi': '19', 'pressurem': '1009', 'pressurei': '29.81', 'windchillm': '-999', 'windchilli': '-999', 'heatindexm': '-9999', 'heatindexi': '-9999', 'precipm': '', 'precipi': '', 'conds': '', 'icon': '', 'fog': '0', 'rain': '0', 'snow': '0', 'hail': '0', 'thunder': '0', 'tornado': '0', 'metar': 'AAXX 02234 08181 45/80 /3607 10051 21059 30088 40094 51010'}, {'date': {'pretty': '12:00 AM CET on February 03, 2018', 'year': '2018', 'mon': '02', 'mday': '03', 'hour': '00', 'min': '00', 'tzname': 'Europe/Madrid'}, 'utcdate': {'pretty': '11:00 PM GMT on February 02, 2018', 'year': '2018', 'mon': '02', 'mday': '02', 'hour': '23', 'min': '00', 'tzname': 'UTC'}, 'tempm': '5.0', 'tempi': '41.0', 'dewptm': '-6.0', 'dewpti': '21.2', 'hum': '45', 'wspdm': '18.5', 'wspdi': '11.5', 'wgustm': '-9999.0', 'wgusti': '-9999.0', 'wdird': '320', 'wdire': 'NW', 'vism': '-9999.0', 'visi': '-9999.0', 'pressurem': '1009', 'pressurei': '29.80', 'windchillm': '1.3', 'windchilli': '34.3', 'heatindexm': '-9999', 'heatindexi': '-9999', 'precipm': '-9999.00', 'precipi': '-9999.00', 'conds': 'Clear', 'icon': 'clear', 'fog': '0', 'rain': '0', 'snow': '0', 'hail': '0', 'thunder': '0', 'tornado': '0', 'metar': 'METAR LEBL 022300Z 32010KT CAVOK 05/M06 Q1009 NOSIG'}, {'date': {'pretty': '12:30 AM CET on February 03, 2018', 'year': '2018', 'mon': '02', 'mday': '03', 'hour': '00', 'min': '30', 'tzname': 'Europe/Madrid'}, 'utcdate': {'pretty': '11:30 PM GMT on February 02, 2018', 'year': '2018', 'mon': '02', 'mday': '02', 'hour': '23', 'min': '30', 'tzname': 'UTC'}, 'tempm': '4.0', 'tempi': '39.2', 'dewptm': '-6.0', 'dewpti': '21.2', 'hum': '49', 'wspdm': '18.5', 'wspdi': '11.5', 'wgustm': '-9999.0', 'wgusti': '-9999.0', 'wdird': '320', 'wdire': 'NW', 'vism': '-9999.0', 'visi': '-9999.0', 'pressurem': '1009', 'pressurei': '29.80', 'windchillm': '0.0', 'windchilli': '32.0', 'heatindexm': '-9999', 'heatindexi': '-9999', 'precipm': '-9999.00', 'precipi': '-9999.00', 'conds': 'Clear', 'icon': 'clear', 'fog': '0', 'rain': '0', 'snow': '0', 'hail': '0', 'thunder': '0', 'tornado': '0', 'metar': 'METAR LEBL 022330Z 32010KT CAVOK 04/M06 Q1009 NOSIG'}, {'date': {'pretty': '1:00 AM CET on February 03, 2018', 'year': '2018', 'mon': '02', 'mday': '03', 'hour': '01', 'min': '00', 'tzname': 'Europe/Madrid'}, 'utcdate': {'pretty': '12:00 AM GMT on February 03, 2018', 'year': '2018', 'mon': '02', 'mday': '03', 'hour': '00', 'min': '00', 'tzname': 'UTC'}, 'tempm': '4.0', 'tempi': '39.2', 'dewptm': '-6.0', 'dewpti': '21.2', 'hum': '49', 'wspdm': '20.4', 'wspdi': '12.7', 'wgustm': '-9999.0', 'wgusti': '-9999.0', 'wdird': '320', 'wdire': 'NW', 'vism': '-9999.0', 'visi': '-9999.0', 'pressurem': '1009', 'pressurei': '29.80', 'windchillm': '-0.2', 'windchilli': '31.6', 'heatindexm': '-9999', 'heatindexi': '-9999', 'precipm': '-9999.00', 'precipi': '-9999.00', 'conds': 'Clear', 'icon': 'clear', 'fog': '0', 'rain': '0', 'snow': '0', 'hail': '0', 'thunder': '0', 'tornado': '0', 'metar': 'METAR LEBL 030000Z 32011KT CAVOK 04/M06 Q1009 NOSIG'}, {'date': {'pretty': '1:30 AM CET on February 03, 2018', 'ye ...

# %%
df_origin = pd.DataFrame(contenido)
df_origin
# Out:
#                                                           history  \
# dailysummary    [{'date': {'pretty': '12:00 AM CET on February...
# date            {'pretty': 'February 3, 2018', 'year': '2018',...
# features                                                      NaN
# observations    [{'date': {'pretty': '12:00 AM CET on February...
# termsofService                                                NaN
# utcdate         {'pretty': 'February 2, 2018', 'year': '2018',...
# version                                                       NaN
#
#                                                          response
# dailysummary                                                  NaN
# date                                                          NaN
# features                                           {'history': 1}
# observations                                                  NaN
# termsofService  http://www.wunderground.com/weather/api/d/term...
# utcdate                                                       NaN
# version                                                       0.1

# %% [markdown]
# Es necesario utilizar la función pandas.io.json.json_normalize para "normalizar" los datos json semiestructurados en una tabla plana. <br>
# Puesto que los datos de interés se encuentran en la fila "observations", se aplica la función a dicha fila.

# %%
df_obs = pd.io.json.json_normalize(contenido['history']['observations'])
df_obs.head(5)
# Out:
#    conds date.hour date.mday date.min date.mon  \
# 0               00        03       00       02
# 1  Clear        00        03       00       02
# 2  Clear        00        03       30       02
# 3  Clear        01        03       00       02
# 4  Clear        01        03       30       02
#
#                          date.pretty    date.tzname date.year dewpti dewptm  \
# 0  12:00 AM CET on February 03, 2018  Europe/Madrid      2018     21     -6
# 1  12:00 AM CET on February 03, 2018  Europe/Madrid      2018   21.2   -6.0
# 2  12:30 AM CET on February 03, 2018  Europe/Madrid      2018   21.2   -6.0
# 3   1:00 AM CET on February 03, 2018  Europe/Madrid      2018   21.2   -6.0
# 4   1:30 AM CET on February 03, 2018  Europe/Madrid      2018   19.4   -7.0
#
#    ...      visi     vism wdird  wdire   wgusti   wgustm windchilli  \
# 0  ...        19       30     0  North                         -999
# 1  ...   -9999.0  -9999.0   320     NW  -9999.0  -9999.0       34.3
# 2  ...   -9999.0  -9999.0   320     NW  -9999.0  -9999.0       32.0
# 3  ...   -9999.0  -9999.0   320     NW  -9999.0  -9999.0       31.6
# 4  ...   -9999.0  -9999.0   330    NNW  -9999.0  -9999.0       36.4
#
#   windchillm wspdi wspdm
# 0       -999   8.1  13.0
# 1        1.3  11.5  18.5
# 2        0.0  11.5  18.5
# 3       -0.2  12.7  20.4
# 4        2.5   6.9  11.1
#
# [5 rows x 44 columns]

# %% [markdown]
# Se estudian las series de interés en el DataFrame. Para ello, primeramente hay que saber qué series contiene el DataFrame

# %%
df_obs.columns
# Out:
# Index(['conds', 'date.hour', 'date.mday', 'date.min', 'date.mon',
#        'date.pretty', 'date.tzname', 'date.year', 'dewpti', 'dewptm', 'fog',
#        'hail', 'heatindexi', 'heatindexm', 'hum', 'icon', 'metar', 'precipi',
#        'precipm', 'pressurei', 'pressurem', 'rain', 'snow', 'tempi', 'tempm',
#        'thunder', 'tornado', 'utcdate.hour', 'utcdate.mday', 'utcdate.min',
#        'utcdate.mon', 'utcdate.pretty', 'utcdate.tzname', 'utcdate.year',
#        'visi', 'vism', 'wdird', 'wdire', 'wgusti', 'wgustm', 'windchilli',
#        'windchillm', 'wspdi', 'wspdm'],
#       dtype='object')

# %% [markdown]
# Se crea un nuevo DataFrame llamado "df_filter" formado por las series de "df_obs" que son de interés. En este caso se escogen "date.mday", "date.mon", "date.year", "date.hour", "date.min", "tempm", "pressure" y "hum".

# %%
df_filter = df[['date.mday', 'date.mon', 'date.year', 'date.hour', 'date.min', 'tempm', 'pressurem', 'hum']]
df_filter.head(5)
# Out:
#   date.mday date.mon date.year date.hour date.min tempm pressurem hum
# 0        03       02      2018        00       00     5      1009  32
# 1        03       02      2018        00       00   5.0      1009  45
# 2        03       02      2018        00       30   4.0      1009  49
# 3        03       02      2018        01       00   4.0      1009  49
# 4        03       02      2018        01       30   5.0      1009  42

# %% [markdown]
# Se crea la serie 'date' y se añade al DataFrame "df_filter". Esta nueva serie se crea a partir de la concatenación de las series relativas a la fecha y a la hora, convirtiéndolas a formato datetime.

# %%
df_filter['date'] = pd.to_datetime(df['date.mday'] + '/' + df['date.mon'] + '/' + df['date.year'] + ' ' + df['date.hour'] + ':' + df['date.min'], format = '%d/%m/%Y %H:%M')

df_filter.head(5)
# Out:
# G:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#   date.mday date.mon date.year date.hour date.min tempm pressurem hum  \
# 0        03       02      2018        00       00     5      1009  32
# 1        03       02      2018        00       00   5.0      1009  45
# 2        03       02      2018        00       30   4.0      1009  49
# 3        03       02      2018        01       00   4.0      1009  49
# 4        03       02      2018        01       30   5.0      1009  42
#
#                  date
# 0 2018-02-03 00:00:00
# 1 2018-02-03 00:00:00
# 2 2018-02-03 00:30:00
# 3 2018-02-03 01:00:00
# 4 2018-02-03 01:30:00

# %% [markdown]
# Se crea el nuevo DataFrame "df_dt" en el que se han eliminado las columnas relativas a la fecha y a la hora que no estaban en formato datetime.

# %%
df_dt = df_filter[['date', 'tempm', 'pressurem', 'hum']]
df_dt.head(5)
# Out:
#                  date tempm pressurem hum
# 0 2018-02-03 00:00:00     5      1009  32
# 1 2018-02-03 00:00:00   5.0      1009  45
# 2 2018-02-03 00:30:00   4.0      1009  49
# 3 2018-02-03 01:00:00   4.0      1009  49
# 4 2018-02-03 01:30:00   5.0      1009  42

# %% [markdown]
# Se renombran las columnas del dataframe "df_dt".

# %%
df_dt.columns = ['Fecha', 'Temperatura', 'Presion', 'Humedad']

# %% [markdown]
# Se forma un nuevo DataFrame "df1" formado por los datos existentes del DataFrame "df_dt". <br>
# Para ello, se crean dos máscaras booleanas. La primera de ellas servirá para filtrar aquellos datos que tengan una hora exacta, mientras que la segunda máscará tendrá como finalidad quedarse con aquellos datos que tengan mayor exactitud (los que contienen ".").

# %%
mascara_hora_exacta = df_dt['Fecha'].dt.minute == 0
mascara_contiene_punto = df_dt['Temperatura'].str.contains('.0')

df1 = df_dt[mascara_hora_exacta & mascara_contiene_punto]
df1.head(5)
# Out:
#                  Fecha Temperatura Presion Humedad
# 1  2018-02-03 00:00:00         5.0    1009      45
# 3  2018-02-03 01:00:00         4.0    1009      49
# 6  2018-02-03 02:00:00         5.0    1009      45
# 9  2018-02-03 03:00:00         5.0    1009      42
# 12 2018-02-03 04:00:00         5.0    1009      45

# %% [markdown]
# Se crea una nueva serie formada por la longitud de la cadena existente en la serie "Temperatura".

# %%
df1['Longitud'] = df1['Temperatura'].str.len()
df1.sample(5)
# Out:
# G:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#                  Fecha Temperatura Presion Humedad  Longitud
# 6  2018-02-03 02:00:00         5.0    1009      45         3
# 63 2018-02-03 21:00:00        10.0    1010      54         4
# 30 2018-02-03 10:00:00         6.0    1013      53         3
# 59 2018-02-03 20:00:00          10    1011      45         2
# 3  2018-02-03 01:00:00         4.0    1009      49         3

# %% [markdown]
# Se ordenan las series por fecha y longitud, de manera descendente, para posteriormente eliminar las fechas duplicadas.

# %%
df2 = df1.sort_values(by = ['Fecha', 'Longitud'], ascending= False)
df2 = df2.drop_duplicates(subset = 'Fecha')
df2 = df2.sort_values(by = 'Fecha')
df2 = df2.reset_index(drop = True)

# %% [markdown]
# Se crea el DataFrame "df_final" en el que se encuentran los resultados filtrados y ordenados, y se ha eliminado la serie "Longitud".

# %%
df_final = df2.drop('Longitud', axis = 1)

# %% [markdown]
# Finalmente, los resultados extraídos mediante la consulta son los siguientes:

# %%
df_final
# Out:
#                  Fecha Temperatura Presion Humedad
# 0  2018-02-03 00:00:00         5.0    1009      45
# 1  2018-02-03 01:00:00         4.0    1009      49
# 2  2018-02-03 02:00:00         5.0    1009      45
# 3  2018-02-03 03:00:00         5.0    1009      42
# 4  2018-02-03 04:00:00         5.0    1009      45
# 5  2018-02-03 05:00:00         5.0    1010      45
# 6  2018-02-03 06:00:00         5.0    1010      45
# 7  2018-02-03 07:00:00         4.0    1010      52
# 8  2018-02-03 08:00:00         4.0    1011      52
# 9  2018-02-03 09:00:00         4.0    1012      56
# 10 2018-02-03 10:00:00         6.0    1013      53
# 11 2018-02-03 11:00:00         9.0    1013      46
# 12 2018-02-03 12:00:00        12.0    1012      35
# 13 2018-02-03 13:00:00        12.0    1011      35
# 14 2018-02-03 14:00:00        11.0    1010      47
# 15 2018-02-03 15:00:00        11.0    1010      47
# 16 2018-02-03 16:00:00        11.0    1010      50
# 17 2018-02-03 17:00:00        12.0    1010      47
# 18 2018-02-03 18:00:00        11.0    1010      50
# 19 2018-02-03 19:00:00        10.0    1010      54
# 20 2018-02-03 20:00:00        10.0    1010      54
# 21 2018-02-03 21:00:00        10.0    1010      54
# 22 2018-02-03 22:00:00         9.0    1010      62
# 23 2018-02-03 23:00:00         8.0    1010      66
